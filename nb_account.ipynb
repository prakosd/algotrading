# %%
from datetime import datetime
from algotrading.backtesting.components.account.api import EIAccount
from algotrading.backtesting.components import ComponentFactory

account: EIAccount = ComponentFactory.create_account(datetime.now(), 100000)
print(account)
print(f"margin: {account.margin}")
account.deposit(datetime.now(), 2500, "2nd Deposit")
account.withdraw(datetime.now(), 500, "1st Withdrawal")
account.deposit(datetime.now(), 5000, "3rd Deposit")
account.withdraw(datetime.now(), 1000, "2nd Withdrawal")
account.reset_balance(datetime.now(), "Let's Go")
account.margin_lock(datetime.now(), 2000, "Pinjem dulu ya")
print(f"margin: {account.margin}")
account.close_trade(datetime.now(), 2000, 10, "Horee")
account.margin_release(datetime.now(), 200, "Aku balikin nih")
account.margin_lock(datetime.now(), 200, "Pinjem dulu ya")
account.margin_lock(datetime.now(), 150, "Pinjem dulu ya")
print(f"margin: {account.margin}")
account.close_trade(datetime.now(), 100, -60, "Damn")
account.margin_release(datetime.now(), 200, "Aku balikin nih")
print(f"{account.DEPOSIT_CURRENCY} {account.actual_balance} (initial: {account.DEPOSIT_CURRENCY} {account.initial_balance})")
print(EIAccount.DEPOSIT_CURRENCY)
print(EIAccount.LEVERAGE)
print(EIAccount.UNIT_SIZE)
account.get_ledger()
# account.clear_ledger()
# Out:
# Account(initial_datetime=datetime.datetime(2024, 1, 28, 19, 20, 39, 157720), initial_balance=100000, actual_balance=100000, margin=0, ledger=[{'datetime': datetime.datetime(2024, 1, 28, 19, 20, 39, 157720), 'transaction': 'DEPOSIT', 'currency': 'USD', 'amount': 100000, 'balance': 100000, 'message': 'Initial Deposit'}])
# margin: 0
# margin: 2000
# margin: 150
# USD 100100 (initial: USD 100000)
# USD
# 100
# 100000
#                                transaction currency  amount  balance  \
# datetime
# 2024-01-28 19:20:39.157720         DEPOSIT      USD  100000   100000
# 2024-01-28 19:20:39.157951         DEPOSIT      USD    2500   102500
# 2024-01-28 19:20:39.157988      WITHDRAWAL      USD    -500   102000
# 2024-01-28 19:20:39.158016         DEPOSIT      USD    5000   107000
# 2024-01-28 19:20:39.158042      WITHDRAWAL      USD   -1000   106000
# 2024-01-28 19:20:39.158069           RESET      USD   -6000   100000
# ...
