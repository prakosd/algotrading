# %%
from datetime import datetime
from algotrading.backtesting.components.account import Account

account = Account(datetime.now(), 100000)
print(account)
print(f"margin: {account.margin}")
account.deposit(datetime.now(), 2500, "2nd Deposit")
account.withdraw(datetime.now(), 500, "1st Withdrawal")
account.deposit(datetime.now(), 5000, "3rd Deposit")
account.withdraw(datetime.now(), 1000, "2nd Withdrawal")
account.reset_balance(datetime.now(), "Let's Go")
account.margin_lock(datetime.now(), 2000, "I owe you this")
print(f"margin: {account.margin}")
account.close_trade(datetime.now(), 2000, 10, "closing my trade")
account.margin_release(datetime.now(), 200, "I return the margin")
account.margin_lock(datetime.now(), 200, "May I borrow this")
account.margin_lock(datetime.now(), 150, "Lend me the money")
print(f"margin: {account.margin}")
account.close_trade(datetime.now(), 100, -60, "I'm closing my trade")
account.margin_release(datetime.now(), 200, "I pay it back")
print(f"{account.DEPOSIT_CURRENCY} {account.actual_balance} (initial: {account.DEPOSIT_CURRENCY} {account.initial_balance})")
print(Account.DEPOSIT_CURRENCY)
print(Account.LEVERAGE)
print(Account.UNIT_SIZE)
account.get_ledger()
# account.clear_ledger()
# Out:
# Account(initial_datetime=datetime.datetime(2024, 5, 27, 18, 53, 14, 552938), initial_balance=100000, actual_balance=100000, margin=0, ledger=[{'datetime': datetime.datetime(2024, 5, 27, 18, 53, 14, 552938), 'transaction': 'DEPOSIT', 'currency': 'USD', 'amount': 100000, 'balance': 100000, 'message': 'Initial Deposit'}])
# margin: 0
# margin: 2000
# margin: 150
# USD 100100 (initial: USD 100000)
# USD
# 100
# 100000
#                                transaction currency  amount  balance  \
# datetime
# 2024-05-27 18:53:14.552938         DEPOSIT      USD  100000   100000
# 2024-05-27 18:53:14.553053         DEPOSIT      USD    2500   102500
# 2024-05-27 18:53:14.553064      WITHDRAWAL      USD    -500   102000
# 2024-05-27 18:53:14.553074         DEPOSIT      USD    5000   107000
# 2024-05-27 18:53:14.553083      WITHDRAWAL      USD   -1000   106000
# 2024-05-27 18:53:14.553092           RESET      USD   -6000   100000
# 2024-05-27 18:53:14.553100     MARGIN_LOCK      USD   -2000    98000
# 2024-05-27 18:53:14.553120  MARGIN_RELEASE      USD    2000   100000
# 2024-05-27 18:53:14.553120    PROFIT_TRADE      USD      10   100010
# 2024-05-27 18:53:14.553130  MARGIN_RELEASE      USD     200   100210
# 2024-05-27 18:53:14.553139     MARGIN_LOCK      USD    -200   100010
# 2024-05-27 18:53:14.553147     MARGIN_LOCK      USD    -150    99860
# 2024-05-27 18:53:14.553166  MARGIN_RELEASE      USD     100    99960
# 2024-05-27 18:53:14.553166      LOSS_TRADE      USD     -60    99900
# 2024-05-27 18:53:14.553175  MARGIN_RELEASE      USD     200   100100
#
#                                          message
# datetime
# 2024-05-27 18:53:14.552938       Initial Deposit
# 2024-05-27 18:53:14.553053           2nd Deposit
# 2024-05-27 18:53:14.553064        1st Withdrawal
# 2024-05-27 18:53:14.553074           3rd Deposit
# 2024-05-27 18:53:14.553083        2nd Withdrawal
# 2024-05-27 18:53:14.553092              Let's Go
# 2024-05-27 18:53:14.553100        I owe you this
# 2024-05-27 18:53:14.553120      closing my trade
# 2024-05-27 18:53:14.553120      closing my trade
# 2024-05-27 18:53:14.553130   I return the margin
# 2024-05-27 18:53:14.553139     May I borrow this
# 2024-05-27 18:53:14.553147     Lend me the money
# 2024-05-27 18:53:14.553166  I'm closing my trade
# 2024-05-27 18:53:14.553166  I'm closing my trade
# 2024-05-27 18:53:14.553175         I pay it back
