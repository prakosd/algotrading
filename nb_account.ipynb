# %%
from datetime import datetime
from algotrading.backtesting.account.api import EIAccount
from algotrading.backtesting.account.implementation import Account

account: EIAccount = Account(datetime.now(), 100000)
print(account)
print(f"margin: {account.margin}")
account.deposit(datetime.now(), 2500, "2nd Deposit")
account.withdraw(datetime.now(), 500, "1st Withdrawal")
account.deposit(datetime.now(), 5000, "3rd Deposit")
account.withdraw(datetime.now(), 1000, "2nd Withdrawal")
account.reset_balance(datetime.now(), "Let's Go")
account.margin_lock(datetime.now(), 2000, "Pinjem dulu ya")
print(f"margin: {account.margin}")
account.close_trade(datetime.now(), 2000, 10, "Horee")
account.margin_release(datetime.now(), 200, "Aku balikin nih")
account.margin_lock(datetime.now(), 200, "Pinjem dulu ya")
account.margin_lock(datetime.now(), 150, "Pinjem dulu ya")
print(f"margin: {account.margin}")
account.close_trade(datetime.now(), 100, -60, "Damn")
account.margin_release(datetime.now(), 200, "Aku balikin nih")
print(f"{account.BASE_CURRENCY} {account.actual_balance} (initial: {account.BASE_CURRENCY} {account.initial_balance})")
print(Account.BASE_CURRENCY)
print(Account.LEVERAGE)
print(Account.UNIT_SIZE)
account.get_ledger()
# account.clear_ledger()
# Out:
# Account(initial_datetime=datetime.datetime(2023, 12, 29, 0, 6, 48, 490898), initial_balance=100000, actual_balance=100000, margin=0, ledger=[{'datetime': datetime.datetime(2023, 12, 29, 0, 6, 48, 490898), 'transaction': 'DEPOSIT', 'currency': 'USD', 'amount': 100000, 'balance': 100000, 'message': 'Initial Deposit'}])
# margin: 0
# margin: 2000
# margin: 150
# USD 100100 (initial: USD 100000)
# USD
# 100.0
# 100000
#                                transaction currency  amount  balance  \
# datetime
# 2023-12-29 00:06:48.490898         DEPOSIT      USD  100000   100000
# 2023-12-29 00:06:48.493447         DEPOSIT      USD    2500   102500
# 2023-12-29 00:06:48.493485      WITHDRAWAL      USD    -500   102000
# 2023-12-29 00:06:48.493512         DEPOSIT      USD    5000   107000
# 2023-12-29 00:06:48.493537      WITHDRAWAL      USD   -1000   106000
# 2023-12-29 00:06:48.493562           RESET      USD   -6000   100000
# 2023-12-29 00:06:48.493586     MARGIN_LOCK      USD   -2000    98000
# 2023-12-29 00:06:48.493641  MARGIN_RELEASE      USD    2000   100000
# 2023-12-29 00:06:48.493641    PROFIT_TRADE      USD      10   100010
# 2023-12-29 00:06:48.493718  MARGIN_RELEASE      USD     200   100210
# 2023-12-29 00:06:48.493761     MARGIN_LOCK      USD    -200   100010
# 2023-12-29 00:06:48.493790     MARGIN_LOCK      USD    -150    99860
# 2023-12-29 00:06:48.493850  MARGIN_RELEASE      USD     100    99960
# 2023-12-29 00:06:48.493850      LOSS_TRADE      USD     -60    99900
# 2023-12-29 00:06:48.493875  MARGIN_RELEASE      USD     200   100100
#
#                                     message
# datetime
# 2023-12-29 00:06:48.490898  Initial Deposit
# 2023-12-29 00:06:48.493447      2nd Deposit
# 2023-12-29 00:06:48.493485   1st Withdrawal
# 2023-12-29 00:06:48.493512      3rd Deposit
# 2023-12-29 00:06:48.493537   2nd Withdrawal
# 2023-12-29 00:06:48.493562         Let's Go
# 2023-12-29 00:06:48.493586   Pinjem dulu ya
# 2023-12-29 00:06:48.493641            Horee
# 2023-12-29 00:06:48.493641            Horee
# 2023-12-29 00:06:48.493718  Aku balikin nih
# 2023-12-29 00:06:48.493761   Pinjem dulu ya
# 2023-12-29 00:06:48.493790   Pinjem dulu ya
# 2023-12-29 00:06:48.493850             Damn
# 2023-12-29 00:06:48.493850             Damn
# 2023-12-29 00:06:48.493875  Aku balikin nih
