# %%
from algotrading.backtesting.strategies import StrategyFactory
from algotrading.providers.api import EIProvider
from algotrading.common.trade import Timeframe
from algotrading.common.symbol import Symbol
from algotrading.backtesting.strategies import BuyAndHoldParams

buyandhold = StrategyFactory.create_buyandhold(
    provider_name   = EIProvider.PROVIDER_OANDA,
    symbol          = Symbol.EUR_USD,
    start_date      = "2018-01-01",
    end_date        = "2023-07-31",
    timeframe       = Timeframe.HOUR_4,
    params          = BuyAndHoldParams(
        balance = 10000,
        volume  = 0.1
    ),
    force_download_ticker = False
)

buyandhold.run()
# Out:
# Iteration: 8684 of 8684 (100%)

# %%
buyandhold.get_report(do_print=True)
# Out:
# BACKTESTING REPORT
# 1. Summary
#     ◦ Ticks: 8684
#     ◦ Initial Balance: 10000
#     ◦ Final Balance: 9005.0
#     ◦ Net Profit: -995.0
#     ◦ Gross Profit: 0
#     ◦ Gross Loss: -995.0
# 2. Drawdown
#    Balance Drawdown
#     ◦ Abs: 995.0, Max: 995.0, Rel: 9.95
#    Equity Drawdown
#     ◦ Abs: 2466.4, Max: 2998.7, Rel: 28.47
# 3. Measurement
#     ◦ Profit Factor: 0.0
#     ◦ Recovery Factor: -0.33
#     ◦ Expected Payoff: -995.0
#     ◦ Margin Level: 6269.48
# 4. Trade
#     ◦ All Position:
#        ◦ Total: 1, Won: 0, Lost: 1
#     ◦ Long Position:
#        ◦ Total: 1, Won: 0, Lost: 1
#     ◦ Short Position:
#        ◦ Total: 0, Won: 0, Lost: 0
#     ◦ Total Orders: 2
#     ◦ Total Deals: 2
#     ◦ Largest Profit: 0
#     ◦ Largest Loss: -995.0
#     ◦ Average Profit: 0
#     ◦ Average Loss: -995.0
#     ◦ Max Consecutive Wins:
#        ◦ Total: 0, Profit: 0
#        ◦ Average: 0
#     ◦ Max Consecutive Losses:
#        ◦ Total: 1, Profit: -995.0
#        ◦ Average: 1.0
# BacktestingReport(summary=SummaryReport(ticks=8684, initial_balance=10000, final_balance=9005.0, net_profit=-994.9999999999993, gross_profit=0, gross_loss=-994.9999999999993), balance_drawdown=DrawdownReport(abs=995.0, max=995.0, rel=9.950000000000001), equity_drawdown=DrawdownReport(abs=2466.3999999999996, max=2998.7000000000007, rel=28.47146397273151), measurement=MeasurementReport(profit_factor=0.0, recovery_factor=-0.3318104511955178, expected_payoff=-994.9999999999993, margin_level=6269.4839509666035), trade=TradeReport(all_position=PositionReport(total=1, won=0, lost=1), long_position=PositionReport(total=1, won=0, lost=1), short_position=PositionReport(total=0, won=0, lost=0), total_orders=2, total_deals=2, largest_profit=0, largest_loss=-994.9999999999993, average_profit=0, average_loss=-994.9999999999993, max_consecutive_wins=[0, 0], max_consecutive_losses=[1, -994.9999999999993], avg_consecutive_wins=0, avg_consecutive_losses=1.0))

# %%
buyandhold.plot_equity_records()

# %%
buyandhold.get_equity_records()
# Out:
#                            balance  rProfit   equity  fProfit  marginUsed  \
# datetime
# 2018-01-01 22:00:00+00:00  10000.0      0.0   9998.6     -1.4     120.163
# 2018-01-02 02:00:00+00:00  10000.0      0.0  10007.5      7.5     120.163
# 2018-01-02 06:00:00+00:00  10000.0      0.0  10053.5     53.5     120.163
# 2018-01-02 10:00:00+00:00  10000.0      0.0  10040.6     40.6     120.163
# 2018-01-02 14:00:00+00:00  10000.0      0.0  10027.6     27.6     120.163
# ...                            ...      ...      ...      ...         ...
# 2023-07-28 05:00:00+00:00  10000.0      0.0   8942.5  -1057.5     120.163
# 2023-07-28 09:00:00+00:00  10000.0      0.0   8992.3  -1007.7     120.163
# 2023-07-28 13:00:00+00:00  10000.0      0.0   9008.5   -991.5     120.163
# 2023-07-28 17:00:00+00:00  10000.0      0.0   8996.8  -1003.2     120.163
# 2023-07-30 21:00:00+00:00   9005.0   -995.0   9005.0      0.0       0.000
#
#                            freeMargin  marginLevel marginHealth
# datetime
# 2018-01-01 22:00:00+00:00    9878.437  8320.864160           OK
# 2018-01-02 02:00:00+00:00    9887.337  8328.270766           OK
# 2018-01-02 06:00:00+00:00    9933.337  8366.552100           OK
# 2018-01-02 10:00:00+00:00    9920.437  8355.816682           OK
# 2018-01-02 14:00:00+00:00    9907.437  8344.998044           OK
# ...                               ...          ...          ...
# 2023-07-28 05:00:00+00:00    8822.337  7441.974651           OK
# 2023-07-28 09:00:00+00:00    8872.137  7483.418357           OK
# 2023-07-28 13:00:00+00:00    8888.337  7496.900044           OK
# 2023-07-28 17:00:00+00:00    8876.637  7487.163270           OK
# 2023-07-30 21:00:00+00:00    9005.000     0.000000           OK
#
# [8684 rows x 8 columns]

# %%
buyandhold.account_ledger()
# Out:
#                               transaction currency     amount    balance  \
# datetime
# 2018-01-01 22:00:00+00:00         DEPOSIT      USD  10000.000  10000.000
# 2018-01-01 22:00:00+00:00     MARGIN_LOCK      USD   -120.163   9879.837
# 2023-07-30 21:00:00+00:00  MARGIN_RELEASE      USD    120.163  10000.000
# 2023-07-30 21:00:00+00:00      LOSS_TRADE      USD   -995.000   9005.000
#
#                                    message
# datetime
# 2018-01-01 22:00:00+00:00  Initial Deposit
# 2018-01-01 22:00:00+00:00             None
# 2023-07-30 21:00:00+00:00             None
# 2023-07-30 21:00:00+00:00             None

# %%
buyandhold.get_positions()
# Out:
#      symbol              openDatetime             closeDatetime      type  \
# id
# 0   EUR_USD 2018-01-01 22:00:00+00:00 2023-07-30 21:00:00+00:00  LONG_BUY
#
#     volume comment status   margin  profit
# id
# 0      0.1    None  CLOSE  120.163  -995.0

# %%
buyandhold.get_data()
# Out:
#                                ask      bid      mid  volume  digit  spread  \
# time
# 2018-01-01 22:00:00+00:00  1.20163  1.20149  1.20156    5267      5      14
# 2018-01-02 02:00:00+00:00  1.20252  1.20238  1.20245    2373      5      14
# 2018-01-02 06:00:00+00:00  1.20713  1.20698  1.20706    6494      5      15
# 2018-01-02 10:00:00+00:00  1.20582  1.20569  1.20576    7660      5      13
# 2018-01-02 14:00:00+00:00  1.20452  1.20439  1.20446   10694      5      13
# ...                            ...      ...      ...     ...    ...     ...
# 2023-07-28 05:00:00+00:00  1.09605  1.09588  1.09596   33091      5      17
# 2023-07-28 09:00:00+00:00  1.10102  1.10086  1.10094   25234      5      16
# 2023-07-28 13:00:00+00:00  1.10264  1.10248  1.10256   27920      5      16
# 2023-07-28 17:00:00+00:00  1.10211  1.10131  1.10171   12078      5      80
# 2023-07-30 21:00:00+00:00  1.10231  1.10213  1.10222    7677      5      18
#
#                             returns
# time
# 2018-01-01 22:00:00+00:00       NaN
# 2018-01-02 02:00:00+00:00  0.000740
# 2018-01-02 06:00:00+00:00  0.003827
# 2018-01-02 10:00:00+00:00 -0.001078
# 2018-01-02 14:00:00+00:00 -0.001079
# ...                             ...
# 2023-07-28 05:00:00+00:00 -0.001204
# 2023-07-28 09:00:00+00:00  0.004534
# 2023-07-28 13:00:00+00:00  0.001470
# 2023-07-28 17:00:00+00:00 -0.000771
# 2023-07-30 21:00:00+00:00  0.000463
#
# [8684 rows x 7 columns]

# %%
buyandhold.get_orders()
# Out:
#      symbol                  datetime         type   direction  volume  \
# id
# 0   EUR_USD 2018-01-01 22:00:00+00:00   MARKET_BUY   MARKET_IN     0.1
# 1   EUR_USD 2023-07-30 21:00:00+00:00  MARKET_SELL  MARKET_OUT     0.1
#
#       price
# id
# 0   1.20163
# 1   1.10213

# %%
buyandhold.get_deals()
# Out:
#      symbol                  datetime  type  volume    price
# id
# 0   EUR_USD 2018-01-01 22:00:00+00:00   BUY     0.1  1.20163
# 1   EUR_USD 2023-07-30 21:00:00+00:00  SELL     0.1  1.10213
