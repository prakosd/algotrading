# %%
from algotrading.common.enums import Timeframe
from algotrading.providers.api import EIProvider
from algotrading.providers import ProviderFactory

provider = ProviderFactory.create_provider_by_name(
    name = EIProvider.PROVIDER_OANDA,
    symbol = "EUR_USD",
    start = "2023-01-01",
    end = "2023-06-30",
    timeframe = Timeframe.HOUR_1
)

ticker = provider.get_ticker()
print(ticker)
print(ticker.symbol)
print(ticker.timeframe)
print(ticker.get_digit())
tick = ticker.get_data(-1)
print(tick)
tick = ticker.get_data(datetime = "2023-01-02 14:00:00+00:00")
print(tick)
data = ticker.get_data()
print(data.index[1])
print(ticker.get_timezone())
# Out:
# Ticker(symbol='EUR_USD', start='2023-01-01', end='2023-06-30', timeframe=<Timeframe.HOUR_1: Timeframe(id=5, granularity='H1', resample='1H', description='1 Hour')>, data=                               ask      bid      mid  volume  digit  spread
# time
# 2023-01-01 23:00:00+00:00  1.07082  1.07032  1.07057      25      5      50
# 2023-01-02 00:00:00+00:00  1.07097  1.07047  1.07072      76      5      50
# 2023-01-02 01:00:00+00:00  1.07010  1.06960  1.06985      73      5      50
# 2023-01-02 02:00:00+00:00  1.06976  1.06926  1.06951      35      5      50
# 2023-01-02 03:00:00+00:00  1.06983  1.06933  1.06958      83      5      50
# ...                            ...      ...      ...     ...    ...     ...
# 2023-06-29 19:00:00+00:00  1.08698  1.08685  1.08692    2529      5      13
# 2023-06-29 20:00:00+00:00  1.08652  1.08635  1.08644    1315      5      17
# 2023-06-29 21:00:00+00:00  1.08666  1.08624  1.08645     223      5      42
# 2023-06-29 22:00:00+00:00  1.08665  1.08649  1.08657     885      5      16
# 2023-06-29 23:00:00+00:00  1.08682  1.08667  1.08674     835      5      15
#
# [3098 rows x 6 columns])
# EUR_USD
# Timeframe.HOUR_1
# 5
# EITick(symbol='EUR_USD', datetime=Timestamp('2023-06-29 23:00:00+0000', tz='UTC'), ask=1.08682, bid=1.08667, mid=1.08674, volume=835, digit=5, spread=15)
# EITick(symbol='EUR_USD', datetime=Timestamp('2023-01-02 14:00:00+0000', tz='UTC'), ask=1.06739, bid=1.06712, mid=1.06726, volume=1351, digit=5, spread=27)
# 2023-01-02 00:00:00+00:00
# UTC

# %%
ticker.analyze()
# Out:
#            volume     spread      change         mean  cover      color
# hour
# 0     2835.279070  15.643411   51.465116  4326.783472   True       gray
# 1     3407.992248  15.596899   61.023256  4326.783472   True       gray
# 2     2883.294574  15.356589   50.573643  4326.783472   True       gray
# 3     2236.744186  15.116279   38.193798  4326.783472   True       gray
# 4     1944.527132  15.217054   33.728682  4326.783472   True       gray
# 5     2488.224806  15.612403   44.945736  4326.783472   True       gray
# 6     3776.434109  15.387597   67.372093  4326.783472   True       gray
# 7     5736.627907  15.217054   99.054264  4326.783472   True  darkgreen
# 8     6195.705426  15.255814  100.193798  4326.783472   True  darkgreen
# 9     5276.744186  14.968992   98.217054  4326.783472   True  darkgreen
# 10    4545.674419  14.542636   74.992248  4326.783472   True  darkgreen
# 11    4532.751938  14.589147   85.720930  4326.783472   True  darkgreen
# 12    6747.596899  14.201550  121.899225  4326.783472   True  darkgreen
# 13    8823.255814  15.666667  132.542636  4326.783472   True  darkgreen
# 14    9652.689922  15.000000  140.550388  4326.783472   True  darkgreen
# 15    8473.038760  13.713178  120.961240  4326.783472   True  darkgreen
# 16    5521.782946  14.085271   77.627907  4326.783472   True  darkgreen
# 17    4045.589147  14.883721   73.581395  4326.783472   True       gray
# 18    4211.837209  15.062016   71.930233  4326.783472   True       gray
# 19    3959.643411  14.813953   54.744186  4326.783472   True       gray
# 20    2348.457364  18.829457   37.356589  4326.783472   True       gray
# 21    1001.046154  38.146154   25.192308  4326.783472  False        red
# 22    1589.542636  26.953488   27.852713  4326.783472   True       gray
# 23    1608.323077  16.130769   34.823077  4326.783472   True       gray

# %%
ticker.plot()

# %%
ticker.resample(Timeframe.DAY_1)
print(ticker.timeframe)
ticker.plot()
# Out:
# EUR_USD - Resampling 1 Hour -> 1 Day successful
# Timeframe.DAY_1

# %%
from algotrading.common.enums import Timeframe
from algotrading.providers.api import EIProvider
from algotrading.providers import ProviderFactory

provider = ProviderFactory.create_provider_by_name(
    name = EIProvider.PROVIDER_OANDA,
    symbol = "AUD_USD",
    start = "2023-06-06",
    end = "2023-06-07",
    timeframe = Timeframe.HOUR_4
)

ticker_a = provider.get_ticker()
print(f"Number of Tick ticker_a: {ticker_a.get_length()}")
ticker_a.get_data()
# Out:
# Number of Tick ticker_a: 7
#                                ask      bid      mid  volume  digit  spread
# time
# 2023-06-05 21:00:00+00:00  0.66144  0.66132  0.66138    3853      5      12
# 2023-06-06 01:00:00+00:00  0.66656  0.66645  0.66650   10172      5      11
# 2023-06-06 05:00:00+00:00  0.66573  0.66561  0.66567   14420      5      12
# 2023-06-06 09:00:00+00:00  0.66523  0.66512  0.66518    8853      5      11
# 2023-06-06 13:00:00+00:00  0.66737  0.66723  0.66730   13493      5      14
# 2023-06-06 17:00:00+00:00  0.66722  0.66706  0.66714    5283      5      16
# 2023-06-06 21:00:00+00:00  0.66826  0.66814  0.66820    4513      5      12

# %%
from algotrading.common.enums import Timeframe
from algotrading.providers.api import EIProvider
from algotrading.providers import ProviderFactory

provider = ProviderFactory.create_provider_by_name(
    name = EIProvider.PROVIDER_OANDA,
    symbol = "AUD_USD",
    start = "2023-06-07",
    end = "2023-06-08",
    timeframe = Timeframe.HOUR_4
)

ticker_b = provider.get_ticker()
print(f"Number of Tick ticker_b: {ticker_b.get_length()}")
ticker_b.get_data()
# Out:
# Number of Tick ticker_b: 7
#                                ask      bid      mid  volume  digit  spread
# time
# 2023-06-06 21:00:00+00:00  0.66826  0.66814  0.66820    4513      5      12
# 2023-06-07 01:00:00+00:00  0.66805  0.66792  0.66798    9720      5      13
# 2023-06-07 05:00:00+00:00  0.66911  0.66897  0.66904    9680      5      14
# 2023-06-07 09:00:00+00:00  0.66886  0.66872  0.66879    8471      5      14
# 2023-06-07 13:00:00+00:00  0.66558  0.66546  0.66552   16360      5      12
# 2023-06-07 17:00:00+00:00  0.66537  0.66523  0.66530    7081      5      14
# 2023-06-07 21:00:00+00:00  0.66652  0.66638  0.66645    4776      5      14

# %%
ticker_a.append(ticker_b)
print(f"Number of Tick ticker_a: {ticker_a.get_length()}")
ticker_a.get_data()
# Out:
# Appending successful
# Number of Tick ticker_a: 13
#                                ask      bid      mid  volume  digit  spread
# time
# 2023-06-05 21:00:00+00:00  0.66144  0.66132  0.66138    3853      5      12
# 2023-06-06 01:00:00+00:00  0.66656  0.66645  0.66650   10172      5      11
# 2023-06-06 05:00:00+00:00  0.66573  0.66561  0.66567   14420      5      12
# 2023-06-06 09:00:00+00:00  0.66523  0.66512  0.66518    8853      5      11
# 2023-06-06 13:00:00+00:00  0.66737  0.66723  0.66730   13493      5      14
# 2023-06-06 17:00:00+00:00  0.66722  0.66706  0.66714    5283      5      16
# 2023-06-06 21:00:00+00:00  0.66826  0.66814  0.66820    4513      5      12
# 2023-06-07 01:00:00+00:00  0.66805  0.66792  0.66798    9720      5      13
# 2023-06-07 05:00:00+00:00  0.66911  0.66897  0.66904    9680      5      14
# 2023-06-07 09:00:00+00:00  0.66886  0.66872  0.66879    8471      5      14
# 2023-06-07 13:00:00+00:00  0.66558  0.66546  0.66552   16360      5      12
# 2023-06-07 17:00:00+00:00  0.66537  0.66523  0.66530    7081      5      14
# 2023-06-07 21:00:00+00:00  0.66652  0.66638  0.66645    4776      5      14
